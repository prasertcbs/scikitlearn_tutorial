# %% [markdown]
# ## Unsupervised Learning: Principal Component Analysis (Iris dataset)
# * sklearn doc: https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html

# %% [markdown]
# ---
# * author:  [Prasert Kanawattanachai](prasert.k@chula.ac.th)
# * YouTube: https://www.youtube.com/prasertcbs
# * [Chulalongkorn Business School](https://www.cbs.chula.ac.th/en/)
# ---

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('z8APHNo1iA4', width=720, height=405)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
print(f'pandas  version = {pd.__version__}')
print(f'numpy   version = {np.__version__}')
print(f'seaborn version = {sns.__version__}')
# Out:
# pandas  version = 1.0.3
# numpy   version = 1.18.1
# seaborn version = 0.10.0

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2020-04-19 09:32:06.491201')

# %%
df=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/iris.csv')
df.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 100           6.3          3.3           6.0          2.5   virginica
# 64            5.6          2.9           3.6          1.3  versicolor
# 0             5.1          3.5           1.4          0.2      setosa
# 84            5.4          3.0           4.5          1.5  versicolor
# 102           7.1          3.0           5.9          2.1   virginica
# 142           5.8          2.7           5.1          1.9   virginica
# 56            6.3          3.3           4.7          1.6  versicolor
# 79            5.7          2.6           3.5          1.0  versicolor
# 98            5.1          2.5           3.0          1.1  versicolor
# 78            6.0          2.9           4.5          1.5  versicolor

# %%
df.species.value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
cols=['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
df[cols].hist(layout=(1, len(cols)), figsize=(5 * len(cols), 3.5));

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
dcorr=df[cols].corr()
# dcorr

mask = np.zeros_like(dcorr)
# mask.shape
mask[np.triu_indices_from(mask)] = True

fig, ax = plt.subplots(figsize=(7,5)) 
sns.heatmap(dcorr, cmap=sns.diverging_palette(10, 145, n=100), 
            vmin=-1, vmax=1, center=0, linewidths=1, annot=True, mask=mask, ax=ax);

# %%
sns.pairplot(df, vars=cols, 
             hue='species', 
             markers=['o', 'D', '+'],
             plot_kws={'alpha': .4});

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler # z-score

# %%
df[cols]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# # StandardScaler (z-score)
# $z=\frac{x_i-\bar{x}}{sd}$

# %%
X=df[cols]
scaler = StandardScaler()
X_t=scaler.fit_transform(X)

# %%
scaler.mean_
# Out:
# array([5.84333333, 3.054     , 3.75866667, 1.19866667])

# %%
df[cols].mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
scaler.var_
# Out:
# array([0.68112222, 0.18675067, 3.09242489, 0.57853156])

# %%
np.sqrt(scaler.var_)
# Out:
# array([0.82530129, 0.43214658, 1.75852918, 0.76061262])

# %%
X_t[:5].round(4)
# Out:
# array([[-0.9007,  1.0321, -1.3413, -1.313 ],
#        [-1.143 , -0.125 , -1.3413, -1.313 ],
#        [-1.3854,  0.3378, -1.3981, -1.313 ],
#        [-1.5065,  0.1064, -1.2844, -1.313 ],
#        [-1.0218,  1.2635, -1.3413, -1.313 ]])

# %%
dz=pd.DataFrame(X_t.round(4), columns=[f'z_{c}' for c in cols])
dz
# Out:
#      z_sepal_length  z_sepal_width  z_petal_length  z_petal_width
# 0           -0.9007         1.0321         -1.3413        -1.3130
# 1           -1.1430        -0.1250         -1.3413        -1.3130
# 2           -1.3854         0.3378         -1.3981        -1.3130
# 3           -1.5065         0.1064         -1.2844        -1.3130
# 4           -1.0218         1.2635         -1.3413        -1.3130
# ..              ...            ...             ...            ...
# 145          1.0380        -0.1250          0.8196         1.4480
# 146          0.5533        -1.2820          0.7059         0.9221
# 147          0.7957        -0.1250          0.8196         1.0535
# 148          0.4322         0.8007          0.9334         1.4480
# 149          0.0687        -0.1250          0.7628         0.7906
#
# [150 rows x 4 columns]

# %%
pd.concat([df, dz], axis='columns')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      z_sepal_length  z_sepal_width  z_petal_length  z_petal_width
# 0           -0.9007         1.0321         -1.3413        -1.3130
# 1           -1.1430        -0.1250         -1.3413        -1.3130
# 2           -1.3854         0.3378         -1.3981        -1.3130
# 3           -1.5065         0.1064         -1.2844        -1.3130
# 4           -1.0218         1.2635         -1.3413        -1.3130
# ..              ...            ...             ...            ...
# 145          1.0380        -0.1250          0.8196         1.4480
# 146          0.5533        -1.2820          0.7059         0.9221
# 147          0.7957        -0.1250          0.8196         1.0535
# 148          0.4322         0.8007          0.9334         1.4480
# 149          0.0687        -0.1250          0.7628         0.7906
#
# [150 rows x 9 columns]

# %%
(df['sepal_length']-scaler.mean_[0])/np.sqrt(scaler.var_[0])
# Out:
# 0     -0.900681
# 1     -1.143017
# 2     -1.385353
# 3     -1.506521
# 4     -1.021849
#          ...
# 145    1.038005
# 146    0.553333
# 147    0.795669
# 148    0.432165
# 149    0.068662
# Name: sepal_length, Length: 150, dtype: float64

# %%
X_t[:, 0]
# Out:
# array([-0.90068117, -1.14301691, -1.38535265, -1.50652052, -1.02184904,
#        -0.53717756, -1.50652052, -1.02184904, -1.74885626, -1.14301691,
#        -0.53717756, -1.26418478, -1.26418478, -1.87002413, -0.05250608,
#        -0.17367395, -0.53717756, -0.90068117, -0.17367395, -0.90068117,
#        -0.53717756, -0.90068117, -1.50652052, -0.90068117, -1.26418478,
#        -1.02184904, -1.02184904, -0.7795133 , -0.7795133 , -1.38535265,
#        -1.26418478, -0.53717756, -0.7795133 , -0.41600969, -1.14301691,
#        -1.02184904, -0.41600969, -1.14301691, -1.74885626, -0.90068117,
#        -1.02184904, -1.62768839, -1.74885626, -1.02184904, -0.90068117,
#        -1.26418478, -0.90068117, -1.50652052, -0.65834543, -1.02184904,
#         1.40150837,  0.67450115,  1.2803405 , -0.41600969,  0.79566902,
#        -0.17367395,  0.55333328, -1.14301691,  0.91683689, -0.7795133 ,
#        -1.02184904,  0.06866179,  0.18982966,  0.31099753, -0.29484182,
#         1.03800476, -0.29484182, -0.05250608,  0.4321654 , -0.29484182,
#         0.06866179,  0.31099753,  0.55333328,  0.31099753,  0.67450115,
#         0.91683689,  1.15917263,  1.03800476,  0.18982966, -0.17367395,
#        -0.41600969, -0.41600969, -0.05250608,  0.18982966, -0.53717756,
#         0.18982966,  1.03800476,  0.55333328, -0.29484182, -0.41600969,
#        -0.41600969,  0.31099753, -0.05250608, -1.02184904, -0.29484182,
#        -0.17367395, -0.17367395,  0.4321654 , -0.90068117, -0.17367395,
#         0.55333328, -0.05250608,  1.52267624,  0.55333328,  0.79566902,
#         2.12851559, -1.14301691,  1.76501198,  1.03800476,  1.64384411,
#         0.79566902,  0.67450115,  1.15917263, -0.17367395, -0.05250608,
#         0.67450115,  0.79566902,  2.24968346,  2.24968346,  0.18982966,
#         1.2803405 , -0.29484182,  2.24968346,  0.55333328,  1.03800476,
#         1.64384411,  0.4321654 ,  0.31099753,  0.67450115,  1.64384411,
#         1.88617985,  2.4920192 ,  0.67450115,  0.55333328,  0.31099753,
#         2.24968346,  0.55333328,  0.67450115,  0.18982966,  1.2803405 ,
#         1.03800476,  1.2803405 , -0.05250608,  1.15917263,  1.03800476,
#         1.03800476,  0.55333328,  0.79566902,  0.4321654 ,  0.06866179])

# %%
X_t[:, 0].mean().round(4)
# Out:
# -0.0

# %%
np.sqrt(X_t[:, 0].var())
# Out:
# 1.0

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
X_t[:5]
# Out:
# array([[-0.90068117,  1.03205722, -1.3412724 , -1.31297673],
#        [-1.14301691, -0.1249576 , -1.3412724 , -1.31297673],
#        [-1.38535265,  0.33784833, -1.39813811, -1.31297673],
#        [-1.50652052,  0.10644536, -1.2844067 , -1.31297673],
#        [-1.02184904,  1.26346019, -1.3412724 , -1.31297673]])

# %%
X_t.shape
# Out:
# (150, 4)

# %%
X_t.shape[1]
# Out:
# 4

# %%
pca = PCA(n_components=X_t.shape[1])
# pca = PCA(n_components=2)

pca.fit_transform(X_t)
print(f'explained_variance (n_components={pca.n_components}) = {pca.explained_variance_}') # Eigenvalues
print(f'explained_variance_ratio (n_components={pca.n_components}) = {pca.explained_variance_ratio_}')
print(f'sum explained_variance_ratio = {np.sum(pca.explained_variance_ratio_)}')
# Out:
# explained_variance (n_components=4) = [2.93035378 0.92740362 0.14834223 0.02074601]
# explained_variance_ratio (n_components=4) = [0.72770452 0.23030523 0.03683832 0.00515193]
# sum explained_variance_ratio = 1.0

# %%
def scree_plot(X, n_components, with_cumulative=False, show_data_label=False, figsize=(10, 7)):
    '''
    PCA scree plot with cumulative
    '''
    scaler = StandardScaler()
    X_t=scaler.fit_transform(X)

    max_components = min(X.shape)
    x=np.arange(1, n_components+1)
    pca = PCA(n_components=max_components)
    pca.fit_transform(X_t)
    y1=pca.explained_variance_ratio_[:n_components]
    y2=np.cumsum(pca.explained_variance_ratio_)[:n_components]
    
    plt.figure(figsize=figsize)
    
    if n_components > 20:
        marker = None
    else:
        marker = 'o'
    if with_cumulative:
        plt.plot(x, y2, linestyle='--', marker=marker, label='cumulative', color='salmon')
        
    plt.plot(x, y1, linestyle='-', marker=marker, label='individual', color='deepskyblue')
    plt.title('explained variance ratio')
    plt.xlabel('# of components')
    plt.ylabel('proportion of variance explained')
    plt.legend()
    if with_cumulative:
        [plt.axhline(y=xl, color='.7', linestyle='--') for xl in [.8, .9, .95, 1]]
    plt.grid(axis='x')

    if show_data_label:
        for n, v, cv in zip(np.nditer(x, flags=['refs_ok']), 
                            np.nditer(y1, flags=['refs_ok']),
                            np.nditer(y2, flags=['refs_ok'])):
                plt.text(n+.02, v+.02, f'{v*100:.2f}%', fontsize=10)
                if with_cumulative:
                    plt.text(n+.02, cv+.02, f'{cv*100:.2f}%', fontsize=10)

# %%
scree_plot(X, 4, True, True)

# %%
scree_plot(X, 4, False, True, (20, 7))

# %%
pca.components_ # Eigenvectors
# Out:
# array([[ 0.52237162, -0.26335492,  0.58125401,  0.56561105],
#        [ 0.37231836,  0.92555649,  0.02109478,  0.06541577],
#        [-0.72101681,  0.24203288,  0.14089226,  0.6338014 ],
#        [-0.26199559,  0.12413481,  0.80115427, -0.52354627]])

# %%
dpc=pd.DataFrame(pca.components_.T, 
                  index=cols,
                  columns=[f'PC{n+1}' for n in range(pca.components_.shape[0])]).round(4) #Eigenvectors
# dpc
dpc.style.applymap(lambda e: 'background-color: yellow' if np.abs(e) > .5 else 'background-color: white')
# Out:
# <style  type="text/css" >
#     #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row0_col0 {
#             background-color:  yellow;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row0_col1 {
#             background-color:  white;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row0_col2 {
#             background-color:  yellow;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row0_col3 {
#             background-color:  white;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row1_col0 {
#             background-color:  white;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row1_col1 {
#             background-color:  yellow;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row1_col2 {
#             background-color:  white;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row1_col3 {
#             background-color:  white;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row2_col0 {
#             background-color:  yellow;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row2_col1 {
#             background-color:  white;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row2_col2 {
#             background-color:  white;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row2_col3 {
#             background-color:  yellow;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row3_col0 {
#             background-color:  yellow;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row3_col1 {
#             background-color:  white;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row3_col2 {
#             background-color:  yellow;
#         }    #T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row3_col3 {
#             background-color:  yellow;
#         }</style><table id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PC1</th>        <th class="col_heading level0 col1" >PC2</th>        <th class="col_heading level0 col2" >PC3</th>        <th class="col_heading level0 col3" >PC4</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5level0_row0" class="row_heading level0 row0" >sepal_length</th>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row0_col0" class="data row0 col0" >0.522400</td>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row0_col1" class="data row0 col1" >0.372300</td>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row0_col2" class="data row0 col2" >-0.721000</td>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row0_col3" class="data row0 col3" >-0.262000</td>
#             </tr>
#             <tr>
#                         <th id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5level0_row1" class="row_heading level0 row1" >sepal_width</th>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row1_col0" class="data row1 col0" >-0.263400</td>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row1_col1" class="data row1 col1" >0.925600</td>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row1_col2" class="data row1 col2" >0.242000</td>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row1_col3" class="data row1 col3" >0.124100</td>
#             </tr>
#             <tr>
#                         <th id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5level0_row2" class="row_heading level0 row2" >petal_length</th>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row2_col0" class="data row2 col0" >0.581300</td>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row2_col1" class="data row2 col1" >0.021100</td>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row2_col2" class="data row2 col2" >0.140900</td>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row2_col3" class="data row2 col3" >0.801200</td>
#             </tr>
#             <tr>
#                         <th id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5level0_row3" class="row_heading level0 row3" >petal_width</th>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row3_col0" class="data row3 col0" >0.565600</td>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row3_col1" class="data row3 col1" >0.065400</td>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row3_col2" class="data row3 col2" >0.633800</td>
#                         <td id="T_fc9b0ae6_81e5_11ea_9e49_28cfe920d4e5row3_col3" class="data row3 col3" >-0.523500</td>
#             </tr>
#     </tbody></table>

# %%
sns.heatmap(dpc, cmap=sns.diverging_palette(10, 145, n=100), linewidths=1, 
            center=0, annot=True, vmin=-1, vmax=1)

# %%
X_t[:5]
# Out:
# array([[-0.90068117,  1.03205722, -1.3412724 , -1.31297673],
#        [-1.14301691, -0.1249576 , -1.3412724 , -1.31297673],
#        [-1.38535265,  0.33784833, -1.39813811, -1.31297673],
#        [-1.50652052,  0.10644536, -1.2844067 , -1.31297673],
#        [-1.02184904,  1.26346019, -1.3412724 , -1.31297673]])

# %%
X_t.shape
# Out:
# (150, 4)

# %%
pca.components_.T.shape
# Out:
# (4, 4)

# %%
# multiply matrix
np.dot(X_t, pca.components_.T)[:5] # equals pca.transform(X_t)
# Out:
# array([[-2.26454173,  0.5057039 , -0.12194335, -0.02307332],
#        [-2.0864255 , -0.65540473, -0.22725083, -0.10320824],
#        [-2.36795045, -0.31847731,  0.05147962, -0.02782523],
#        [-2.30419716, -0.57536771,  0.09886044,  0.06631146],
#        [-2.38877749,  0.6747674 ,  0.02142785,  0.03739729]])

# %%
pca.transform(X_t)[:5]
# Out:
# array([[-2.26454173,  0.5057039 , -0.12194335, -0.02307332],
#        [-2.0864255 , -0.65540473, -0.22725083, -0.10320824],
#        [-2.36795045, -0.31847731,  0.05147962, -0.02782523],
#        [-2.30419716, -0.57536771,  0.09886044,  0.06631146],
#        [-2.38877749,  0.6747674 ,  0.02142785,  0.03739729]])

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
X_t[:1]
# Out:
# array([[-0.90068117,  1.03205722, -1.3412724 , -1.31297673]])

# %%
pca.components_[:1]
# Out:
# array([[ 0.52237162, -0.26335492,  0.58125401,  0.56561105]])

# %%
np.sum(X_t[:1] * pca.components_[:1])
# Out:
# -2.2645417283948994

# %%
pca.n_components_
# Out:
# 4

# %%
df[:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
dd=pd.concat([pd.DataFrame(pca.transform(X_t), 
                           columns=[f'PC{n}' for n in range(1, pca.n_components_ + 1)]), 
              df[['species']]], axis = 'columns')
dd.head()
# Out:
#         PC1       PC2       PC3       PC4 species
# 0 -2.264542  0.505704 -0.121943 -0.023073  setosa
# 1 -2.086426 -0.655405 -0.227251 -0.103208  setosa
# 2 -2.367950 -0.318477  0.051480 -0.027825  setosa
# 3 -2.304197 -0.575368  0.098860  0.066311  setosa
# 4 -2.388777  0.674767  0.021428  0.037397  setosa

# %% [markdown]
# ### Plot PC1 and PC2

# %%
# pca = PCA(n_components=X.shape[1])
pca = PCA(n_components=2)

X_pca=pca.fit_transform(X_t)
print(f'explained_variance (n_components={pca.n_components}) = {pca.explained_variance_}')
print(f'explained_variance_ratio (n_components={pca.n_components}) = {pca.explained_variance_ratio_}')
print(f'sum explained_variance_ratio = {np.sum(pca.explained_variance_ratio_)}')
# Out:
# explained_variance (n_components=2) = [2.93035378 0.92740362]
# explained_variance_ratio (n_components=2) = [0.72770452 0.23030523]
# sum explained_variance_ratio = 0.9580097536148198

# %%
X_pca.shape
# Out:
# (150, 2)

# %%
X_pca[:5]
# Out:
# array([[-2.26454173,  0.5057039 ],
#        [-2.0864255 , -0.65540473],
#        [-2.36795045, -0.31847731],
#        [-2.30419716, -0.57536771],
#        [-2.38877749,  0.6747674 ]])

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
ax.scatter(X_pca[:, 0], X_pca[:, 1], alpha=.5, cmap='Set1', c=df.species.astype('category').cat.codes)

ax.set_xlabel('PC1')
ax.set_ylabel('PC2');

# %% [markdown]
# ## biplot using yellowbrick package

# %%
# pip install yellowbrick
import yellowbrick.features as yb
visualizer = yb.PCA(scale=True, proj_features=True, proj_dim=2)
visualizer.fit_transform(X)
visualizer.show()

# %%
dpc=pd.DataFrame(pca.components_.T, 
                  index=cols,
                  columns=[f'PC{n+1}' for n in range(pca.components_.shape[0])]).round(4) #Eigenvectors
# dpc
dpc.style.applymap(lambda e: 'background-color: yellow' if np.abs(e) > .5 else 'background-color: white')
# Out:
# <style  type="text/css" >
#     #T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row0_col0 {
#             background-color:  yellow;
#         }    #T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row0_col1 {
#             background-color:  white;
#         }    #T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row1_col0 {
#             background-color:  white;
#         }    #T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row1_col1 {
#             background-color:  yellow;
#         }    #T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row2_col0 {
#             background-color:  yellow;
#         }    #T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row2_col1 {
#             background-color:  white;
#         }    #T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row3_col0 {
#             background-color:  yellow;
#         }    #T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row3_col1 {
#             background-color:  white;
#         }</style><table id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PC1</th>        <th class="col_heading level0 col1" >PC2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5level0_row0" class="row_heading level0 row0" >sepal_length</th>
#                         <td id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row0_col0" class="data row0 col0" >0.522400</td>
#                         <td id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row0_col1" class="data row0 col1" >0.372300</td>
#             </tr>
#             <tr>
#                         <th id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5level0_row1" class="row_heading level0 row1" >sepal_width</th>
#                         <td id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row1_col0" class="data row1 col0" >-0.263400</td>
#                         <td id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row1_col1" class="data row1 col1" >0.925600</td>
#             </tr>
#             <tr>
#                         <th id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5level0_row2" class="row_heading level0 row2" >petal_length</th>
#                         <td id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row2_col0" class="data row2 col0" >0.581300</td>
#                         <td id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row2_col1" class="data row2 col1" >0.021100</td>
#             </tr>
#             <tr>
#                         <th id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5level0_row3" class="row_heading level0 row3" >petal_width</th>
#                         <td id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row3_col0" class="data row3 col0" >0.565600</td>
#                         <td id="T_fda863e8_81e5_11ea_9e49_28cfe920d4e5row3_col1" class="data row3 col1" >0.065400</td>
#             </tr>
#     </tbody></table>

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# ### Plot 3D (PC1, PC2, PC3)

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D

# %%
# pca = PCA(n_components=X.shape[1])
pca = PCA(n_components=3)

X_pca=pca.fit_transform(X_t)
print(f'explained_variance (n_components={pca.n_components}) = {pca.explained_variance_}')
print(f'explained_variance_ratio (n_components={pca.n_components}) = {pca.explained_variance_ratio_}')
print(f'sum explained_variance_ratio = {np.sum(pca.explained_variance_ratio_)}')
# Out:
# explained_variance (n_components=3) = [2.93035378 0.92740362 0.14834223]
# explained_variance_ratio (n_components=3) = [0.72770452 0.23030523 0.03683832]
# sum explained_variance_ratio = 0.9948480731910937

# %%
X_pca[:5]
# Out:
# array([[-2.26454173,  0.5057039 , -0.12194335],
#        [-2.0864255 , -0.65540473, -0.22725083],
#        [-2.36795045, -0.31847731,  0.05147962],
#        [-2.30419716, -0.57536771,  0.09886044],
#        [-2.38877749,  0.6747674 ,  0.02142785]])

# %%
# switch to interactive matplotlib
# %matplotlib qt
# %pylab qt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# switch back to inline mode
# %matplotlib inline

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], alpha=.5, cmap='Set1', c=df.species.astype('category').cat.codes)

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3');

# %% [markdown]
# ---
